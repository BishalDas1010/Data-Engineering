# %% [markdown]
# ##gold Layer Data processing

# %%
df_silver= spark.sql("select * from fmcg.silver.customers")
display(df_silver)
df_silver = df_silver.withColumnRenamed("_c0","customer_id")
df_gold = df_silver.select("customer_id","name","city","customer","marker","platform")

# %%
display(df_gold)

# %% [markdown]
# ## LOad the data INto Gold
# ##

# %%
df_gold.write\
.format("delta")\
.mode("overwrite")\
.saveAsTable("fmcg.gold.sb_dim_customers")
